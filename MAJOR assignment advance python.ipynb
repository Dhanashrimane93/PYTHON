# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('honeyproduction 1998-2021.csv')
df
# Out:
#              State    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0          Alabama   16000.0           71   1136000.0    159000.0        0.72
# 1          Arizona   55000.0           60   3300000.0   1485000.0        0.64
# 2         Arkansas   53000.0           65   3445000.0   1688000.0        0.59
# 3       California  450000.0           83  37350000.0  12326000.0        0.62
# 4         Colorado   27000.0           72   1944000.0   1594000.0        0.70
# ..             ...       ...          ...         ...         ...         ...
# 980       Virginia    6000.0           40    240000.0     79000.0        8.23
# 981     Washington   96000.0           32   3072000.0   1206000.0        2.52
# 982  West Virginia    6000.0           43    258000.0    136000.0        4.80
# 983      Wisconsin   42000.0           47   1974000.0    750000.0        2.81
# 984        Wyoming   38000.0           58   2204000.0    242000.0        2.07
#
#       prodvalue  year
# ...

# %%
df.shape
# Out:
# (985, 8)

# %%
df.dtypes
# Out:
# State           object
# numcol         float64
# yieldpercol      int64
# totalprod      float64
# stocks         float64
# priceperlb     float64
# prodvalue      float64
# year             int64
# dtype: object

# %%
df.columns
# Out:
# Index(['State', 'numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb',
#        'prodvalue', 'year'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   State        985 non-null    object
#  1   numcol       985 non-null    float64
#  2   yieldpercol  985 non-null    int64
#  3   totalprod    985 non-null    float64
#  4   stocks       985 non-null    float64
#  5   priceperlb   985 non-null    float64
#  6   prodvalue    985 non-null    float64
#  7   year         985 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 61.7+ KB

# %%
df.isnull().sum()
# Out:
# State          0
# numcol         0
# yieldpercol    0
# totalprod      0
# stocks         0
# priceperlb     0
# prodvalue      0
# year           0
# dtype: int64

# %%
# Q.1 How has honey production yield changed from 1998 to 2021?

# %%
plt.figure(figsize=(15,7))
sns.pointplot(x='year',y='yieldpercol',data=df,estimator=sum,ci=None)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.pointplot(x='year',y='yieldpercol',data=df,estimator=sum,ci=None)
plt.xticks(rotation=90)
plt.show()

# %%
# Observations:
# in contrast to number of colonies the yield per colony has been decresing since 1998.
# as seen in the graph honey production decresing over time

# %%
# Q.2 Over time what are the major production trends across the states?

# %%
plt.figure(figsize=(15,7))
sns.pointplot(x='year',y='totalprod',data=df,estimator=sum,ci=None,hue='State')
plt.legend(bbox_to_anchor=(1,1))
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.pointplot(x='year',y='totalprod',data=df,estimator=sum,ci=None,hue='State')
plt.legend(bbox_to_anchor=(1,1))
plt.xticks(rotation=90)
plt.show()

# %%
#Obsevations:
    #there are some state that have much higher production than the others

# %%
sns.catplot(x='year',y='totalprod',data=df,estimator=sum,col='State',kind='point',
           height=3,col_wrap=5)
plt.show()

# %% [markdown]
# Observations:
# the most prominent honey production states of usa are- california,florida,north dakota
# and south dakota and montana.

# %%
# Q.3 Does the data show any ternds in terms of the number of honey producing colonies and yeild 
  # per colony before 2006,which was when concernover colony collaps disorder spred nationwide?

# %%
plt.figure(figsize=(15,7))
sns.pointplot(x='year',y='yieldpercol',data=colbefore_2006,estimator=sum,ci=None)
plt.xticks(rotation=90)
plt.show()

# %%
# Q.4 Are there any pattern that can be observed between total honey production and
# value of production every year?

# %%
plt.figure(figsize=(25,10))
sns.barplot(x='year',y='prodvalue',data=df.sort_values('totalprod',ascending=False),
           label='production value',color='green',ci=None)
sns.barplot(x='year',y='totalprod',data=df.sort_values('totalprod',ascending=False),
           label='total production',color='red',ci=None,alpha=0.5)
plt.legend(ncol=2,loc='upper left',frameon=True)
plt.show()

# %%
# Q.5 How has the value of production which in some sense could be tied to demand changed every year?

# %%
plt.figure(figsize=(25,10))
sns.barplot(x='year',y='prodvalue',data=df.sort_values('prodvalue',ascending=False),
           color='red',ci=None,alpha=0.8)
plt.title('value of production based on year',size=25)
plt.show()

# %%
# Q.6 construct the related plot using seaborn and matplot apply customization and 
# derive insights from the visualization.
